# %% [markdown]
# # Model Inference on Validation images (env = Conda_Anaconda3)

# %% [markdown]
# <a name="contents2"></a>

# %% [markdown]
# # Contents

# %% [markdown]
# - [Import Libraries](#imports2)
# - [Functions](#functions2)
# - [Pull Data from SingleStore](#pull_data2)
# - [Model Inference](#inference2)
# - [Send predictions to SingleStore](#predictions2)

# %% [markdown]
# <a name="imports2"></a>

# %% [markdown]
# - [Back to Contents](#contents2)

# %% [markdown]
# # Imports

# %%
# Imports
# !pip install PyMySQL
# !pip install torchvision
import numpy as np, pandas as pd
from glob import glob
import shutil, os
import matplotlib.pyplot as plt
from sklearn.model_selection import GroupKFold
from tqdm.notebook import tqdm
import seaborn as sns
import os
import torch
from IPython.display import Image, clear_output
import time
from tqdm.notebook import tqdm
import pymysql
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')

# %%
# Check GPU
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.10.0+cu102 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', major=7, minor=0, total_memory=16160MB, multi_processor_count=80)

# %% [markdown]
# <a name="functions2"></a>

# %% [markdown]
# - [Back to Contents](#contents2)

# %% [markdown]
# # Functions

# %%
# Model format conversion
def yolo2voc(image_height, image_width, bboxes):
    """
    yolo => [xmid, ymid, w, h] (normalized)
    voc  => [x1, y1, x2, y1]
    
    """ 
    bboxes = bboxes.copy().astype(float) # otherwise all value will be 0 as voc_pascal dtype is np.int
    
    bboxes[..., [0, 2]] = bboxes[..., [0, 2]]* image_width
    bboxes[..., [1, 3]] = bboxes[..., [1, 3]]* image_height
    
    bboxes[..., [0, 1]] = bboxes[..., [0, 1]] - bboxes[..., [2, 3]]/2
    bboxes[..., [2, 3]] = bboxes[..., [0, 1]] + bboxes[..., [2, 3]]
    
    return bboxes

# Functions
def GeneralEnsemble(dets, iou_thresh = 0.5, weights=None):
    assert(type(iou_thresh) == float)
    
    ndets = len(dets)
    
    if weights is None:
        w = 1/float(ndets)
        weights = [w]*ndets
    else:
        assert(len(weights) == ndets)
        
        s = sum(weights)
        for i in range(0, len(weights)):
            weights[i] /= s

    out = list()
    used = list()
    
    for idet in range(0,ndets):
        det = dets[idet]
        for box in det:
            if box in used:
                continue
                
            used.append(box)
            # Search the other detectors for overlapping box of same class
            found = []
            for iodet in range(0, ndets):
                odet = dets[iodet]
                
                if odet == det:
                    continue
                
                bestbox = None
                bestiou = iou_thresh
                for obox in odet:
                    if not obox in used:
                        # Not already used
                        if box[4] == obox[4]:
                            # Same class
                            iou = computeIOU(box, obox)
                            if iou > bestiou:
                                bestiou = iou
                                bestbox = obox
                                
                if not bestbox is None:
                    w = weights[iodet]
                    found.append((bestbox,w))
                    used.append(bestbox)
                            
            # Now we've gone through all other detectors
            if len(found) == 0:
                new_box = list(box)
                new_box[5] /= ndets
                out.append(new_box)
            else:
                allboxes = [(box, weights[idet])]
                allboxes.extend(found)
                
                xc = 0.0
                yc = 0.0
                bw = 0.0
                bh = 0.0
                conf = 0.0
                
                wsum = 0.0
                for bb in allboxes:
                    w = bb[1]
                    wsum += w

                    b = bb[0]
                    xc += w*b[0]
                    yc += w*b[1]
                    bw += w*b[2]
                    bh += w*b[3]
                    conf += w*b[5]
                    #print(f"conf = {conf}")
                
                xc /= wsum
                yc /= wsum
                bw /= wsum
                bh /= wsum    

                new_box = [xc, yc, bw, bh, box[4], conf]
                out.append(new_box)
    return out
    
def getCoords(box):
    x1 = float(box[0]) - float(box[2])/2
    x2 = float(box[0]) + float(box[2])/2
    y1 = float(box[1]) - float(box[3])/2
    y2 = float(box[1]) + float(box[3])/2
    return x1, x2, y1, y2
    
def computeIOU(box1, box2):
    x11, x12, y11, y12 = getCoords(box1)
    x21, x22, y21, y22 = getCoords(box2)
    
    x_left   = max(x11, x21)
    y_top    = max(y11, y21)
    x_right  = min(x12, x22)
    y_bottom = min(y12, y22)

    if x_right < x_left or y_bottom < y_top:
        return 0.0    
        
    intersect_area = (x_right - x_left) * (y_bottom - y_top)
    box1_area = (x12 - x11) * (y12 - y11)
    box2_area = (x22 - x21) * (y22 - y21)        
    
    iou = intersect_area / (box1_area + box2_area - intersect_area)
    return iou

# Function to transform the YOLOV5 output to the format the Ensemble function expects. 

def transform_object(df,tmp,flag):
    list_of_floats=[]
    for item in tmp:
        list_of_floats.append(float(item))
        
    tm=int(len(list_of_floats)/6)
    list1=[]
    list2=[]
    checkobj=[]
    for i in range(tm):
          
        j=i*6
        k=j
        l=k+6
            
        checkobj.append(k)
        xmin=list_of_floats[k+2]
        ymin=list_of_floats[k+3]
        xmax=list_of_floats[k+4]
        ymax=list_of_floats[k+5]
            
        box_w=xmax-xmin
        box_h=ymax-ymin
        box_x=xmin+(box_w/2)
        box_y=ymin+box_h/2
            
        list1=[box_x,box_y,box_w,box_h,int(list_of_floats[k]),list_of_floats[k+1]]
        
        list2.append(list1)        
        list1=[]
    if flag==0:
        return checkobj
    else:
        return list2
    
#https://www.kaggle.com/prashantkikani/vinbigdata-ensemble-post-processing?scriptVersionId=56245340

def divide(l, n):
    '''
    divide submission string into group of 6
    '''
    for i in range(0, len(l), n):  
        yield l[i:i + n]

# %% [markdown]
# <a name="pull_data2"></a>

# %% [markdown]
# - [Back to Contents](#contents2)

# %% [markdown]
# # Bring in Dicom header information for Demo Files from SingleStore

# %%
# %%time
os.chdir('/home/ubuntu/vinbigdata/')
s2conn = create_engine('mysql+pymysql://root:Sglstrpw34@172.31.62.112:3306/PatientRecords')

test_df = pd.read_sql_table('ImageHeaderdf', s2conn)
# Out:
# CPU times: user 47.6 ms, sys: 4.56 ms, total: 52.1 ms
# Wall time: 102 ms

# %%
# Show first 5 and last 5 rows
test_df
# Out:
#                                  file  BitsAllocated  BitsStored  Columns  \
# 0    056815f22ac3de9b9eb6fb963d4cfa5a             16          12     3320
# 1    0bfd35d7f2b63b1ef799fefb18605191             16          12     2935
# 2    079de341c7b3804c37114b8da3011b45             16          12     1994
# 3    0764ce517782604a7b81bb6e17c798e9             16          14     2504
# 4    0c6f7b76bcc012fc5a9af4470f735aba             16          12     2701
# ..                                ...            ...         ...      ...
# 209  07cdcea9a6c3049d7a02ade9c680d4d7             16          12     1994
# 210  07fecb6f57a3d452c4764b1013740141             16          12     2304
# 211  0ce3ae82d1f5c69f253432c5ec47c1be             16          14     3072
# 212  090a90ca6e01ed9f613578c95c151a01             16          16     1993
# 213  11b8e52dde21c314c67ead9547b1002a             16          12     1994
#
#      HighBit LossyImageCompression  NumberOfFrames PatientAge PatientSex  \
# 0         11                    00             NaN       None
# 1         11                    00             NaN       None          F
# 2         11                    00             NaN       None          O
# 3         13                    00             NaN       050Y          M
# 4         11                    00             NaN       None
# ..       ...                   ...             ...        ...        ...
# 209       11                    00             NaN       None          O
# 210       11                    00             NaN       None          M
# 211       13                  None             1.0          Y          O
# 212       15                    00             1.0       000Y          F
# 213       11                    00             NaN       None          O
#
#     PhotometricInterpretation  ... WindowCenter  WindowWidth RescaleIntercept  \
# 0                 MONOCHROME2  ...       2048.0       4096.0              0.0
# 1                 MONOCHROME2  ...       2047.0       4095.0              0.0
# 2                 MONOCHROME2  ...       2047.0       4096.0              0.0
# 3                 MONOCHROME2  ...       8191.0      16383.0              0.0
# 4                 MONOCHROME2  ...       2048.0       4096.0              0.0
# ..                        ...  ...          ...          ...              ...
# 209               MONOCHROME2  ...       2047.0       4096.0              0.0
# 210               MONOCHROME1  ...       2047.0       4095.0              0.0
# 211               MONOCHROME2  ...       5023.0       3819.0              0.0
# 212               MONOCHROME2  ...      34967.0      65235.0              NaN
# 213               MONOCHROME2  ...       2047.0       4096.0              0.0
#
#      RescaleSlope  PatientSize  PatientWeight  LargestImagePixelValue  \
# 0             1.0          NaN            NaN                     NaN
# 1             1.0          0.0            0.0                     NaN
# 2             1.0          NaN            NaN                     NaN
# 3             1.0          0.0            0.0                     NaN
# 4             1.0          NaN            NaN                     NaN
# ..            ...          ...            ...                     ...
# 209           1.0          NaN            NaN                     NaN
# 210           1.0          NaN            NaN                     NaN
# 211           1.0          NaN            NaN                     NaN
# 212           NaN          NaN            NaN                     NaN
# 213           1.0          NaN            NaN                     NaN
#
#      SmallestImagePixelValue  LossyImageCompressionMethod  \
# 0                        NaN                         None
# 1                        NaN                         None
# 2                        NaN                         None
# 3                        NaN                         None
# 4                        NaN                         None
# ..                       ...                          ...
# 209                      NaN                         None
# 210                      NaN                         None
# 211                      NaN                         None
# 212                      NaN                         None
# 213                      NaN                         None
#
#      LossyImageCompressionRatio
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 209                         NaN
# 210                         NaN
# 211                         NaN
# 212                         NaN
# 213                         NaN
#
# [214 rows x 25 columns]

# %% [markdown]
# <a name="inference2"></a>

# %% [markdown]
# - [Back to Contents](#contents2)

# %% [markdown]
# # Inference on 5 k-fold ensemble model

# %%
# %%time
fold_exp = ['exp26']
test_dir = f'/home/ubuntu/vinbigdata/DemoConversionToJPG/'
os.chdir('/home/ubuntu/vinbigdata/yolov5')

for fold, exp in enumerate(fold_exp):
    weights_dir = f'/home/ubuntu/vinbigdata/yolov5/runs/train/exp26/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp27/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp28/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp29/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp30/weights/best.pt'
    os.chdir('/home/ubuntu/vinbigdata/yolov5/')
    
    # !python detect.py --weights $weights_dir\
    --img 1024\
    --conf 0.2\
    --iou 0.4\
    --source $test_dir\
    --save-txt --save-conf --exist-ok
    


    image_ids = []
    PredictionStrings = []

    for file_path in tqdm(glob('runs/detect/exp/labels/*txt')):
        image_id = file_path.split('/')[-1].split('.')[0]
        w, h = test_df.loc[test_df.file==image_id,['Columns', 'Rows']].values[0]
        f = open(file_path, 'r')
        data = np.array(f.read().replace('\n', ' ').strip().split(' ')).astype(np.float32).reshape(-1, 6)
        data = data[:, [0, 5, 1, 2, 3, 4]]
        bboxes = list(np.round(np.concatenate((data[:, :2], np.round(yolo2voc(h, w, data[:, 2:]))), axis =1).reshape(-1), 1).astype(str))
        for idx in range(len(bboxes)):
            bboxes[idx] = str(int(float(bboxes[idx]))) if idx%6!=1 else bboxes[idx]
        image_ids.append(image_id)
        PredictionStrings.append(' '.join(bboxes))

    # credit / source: https://www.kaggle.com/awsaf49/vinbigdata-cxr-ad-yolov5-14-class-infer
    pred_df = pd.DataFrame({'file':image_ids,
                            'PredictionString':PredictionStrings})
    # Needs to be the dataframe with 
    df = pd.merge(test_df, pred_df, on = 'file', how = 'left').fillna("14 1 0 0 1 1")
    df = df[['file', 'PredictionString']]

    os.chdir('/home/ubuntu/vinbigdata/')


def convertToBinaryData(ImageFile):
    # Convert digital data to binary format
    with open(ImageFile, 'rb') as file:
        binaryData = file.read()
    return binaryData


def updateBLOB(ImageID, ImagePath, ImageFile):
    #print("Inserting BLOB into JPGImages table")
    # try:
    mycursor = s2conn.cursor()

    sql_update_blob_query = """ Update JPGImages 
                        set PredictionImage = %s 
                        where file = %s """

    jpgImage = convertToBinaryData(ImageFile)

    # Convert data into tuple format
    insert_blob_tuple = (jpgImage, ImageID)
    result = mycursor.execute(sql_update_blob_query, insert_blob_tuple)
    s2conn.commit()
    mycursor.close()
    
    
# Main
directory = '/home/ubuntu/vinbigdata/yolov5/runs/detect/exp'
jpgCount = 0

start = time.time()

s2conn = pymysql.connect(
    user='root',
    password='Sglstrpw34',
    host='172.31.62.112',
    port=3306,
    database='Images')

# iterate over files in
# that directory
for filename in os.listdir(directory):
        f = os.path.join(directory, filename)
        file = os.path.splitext(os.path.basename(os.path.basename(f)))[0]

        # checking if it is a file
        if os.path.isfile(f) and f.endswith(".jpg"):
            updateBLOB(file, directory, f)
            jpgCount += 1
            if jpgCount % 100 == 0:
                print (jpgCount)
print(jpgCount)
s2conn.close()
end = time.time()
print(f'Time to send images with predictions to SingleStore: {round((end - start),2)} seconds')

# remove files and folders from yolov5/runs/detect/exp/
dir = '/home/ubuntu/vinbigdata/yolov5/runs/detect/exp/'
for files in os.listdir(dir):
    path = os.path.join(dir, files)
    try:
        shutil.rmtree(path)
    except OSError:
        os.remove(path)
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# detect: weights=['/home/ubuntu/vinbigdata/yolov5/runs/train/exp26/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp27/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp28/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp29/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp30/weights/best.pt'], source=/home/ubuntu/vinbigdata/DemoConversionToJPG/, imgsz=[1024, 1024], conf_thres=0.2, iou_thres=0.4, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-115-gbc48457 torch 1.10.0+cu102 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Ensemble created with ['/home/ubuntu/vinbigdata/yolov5/runs/train/exp26/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp27/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp28/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp29/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp30/weights/best.pt']
#
# image 1/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/002a34c58c5b758217ed1f584ccbcfe9.jpg: 1024x960 1 Other lesion, 2 Pneumothoraxs, Done. (0.190s)
# image 2/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/004f33259ee4aef671c2b95d54e4be68.jpg: 1024x864 1 Atelectasis, Done. (0.180s)
# image 3/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/008bdde2af2462e86fd373a445d0f4cd.jpg: 1024x832 1 Atelectasis, 1 Other lesion, Done. (0.174s)
# image 4/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/009bc039326338823ca3aa84381f17f1.jpg: 1024x864 1 Atelectasis, 1 Other lesion, 2 Nodule/Masss, Done. (0.180s)
# image 5/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/00a2145de1886cb9eb88869c85d74080.jpg: 1024x928 1 Atelectasis, 1 Other lesion, Done. (0.183s)
# image 6/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/00b7e6bfa4dc1fe9ddd0ce74743e38c2.jpg: 1024x1024 2 Atelectasiss, 1 Pleural effusion, 1 Other lesion, 1 Aortic enlargement, 1 Pleural thickening, Done. (0.188s)
# image 7/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/011295e0bcdc7636569ab73bfdcc4450.jpg: 1024x864 1 Pneumothorax, Done. (0.180s)
# image 8/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/013c169f9dad6f1f6485da961b9f7bf2.jpg: 1024x864 1 Atelectasis, 1 Aortic enlargement, 1 Pneumothorax, 1 Calcification, Done. (0.170s)
# image 9/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/01431a2618c0ace741e4e270a37e20b9.jpg: 1024x832 2 Atelectasiss, 1 Other lesion, Done. (0.174s)
# image 10/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/0168eb925aa6f28a78b16134792f5d0e.jpg: 1024x864 1 Consolidation, 1 Pneumothorax, Done. (0.179s)
# image 11/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/016bc723c3ceedb78e27ebfe7032498e.jpg: 1024x864 1 Atelectasis, 1 Other lesion, 2 Aortic enlargements, Done. (0.171s)
# image 12/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/0171021638f9272a34a41feb84ed47a0.jpg: 1024x1024 Done. (0.188s)
# image 13/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/019df578e38053e614d483f7fb347b26.jpg: 1024x992 1 Atelectasis, 1 Other lesion, 1 Pneumothorax, Done. (0.187s)
# image 14/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/01ded16689539deb30d0981fafd18465.jpg: 1024x896 3 Infiltrations, 5 Calcifications, Done. (0.182s)
# image 15/214 /home/ubuntu/vinbigdata/DemoConversionToJPG
214 /home/ubuntu/vinbigdata/DemoConversionToJPG/1264a14de4ec7c401eaf55b1440e2d20.jpg: 1024x864 1 Atelectasis, 1 Other lesion, Done. (0.179s)
# image 212/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/127c6048347e41fd040ae79d76fdfb3e.jpg: 1024x864 1 Atelectasis, 1 Other lesion, Done. (0.172s)
# image 213/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/127e2784b91becce4ac297255904033e.jpg: 1024x864 Done. (0.172s)
# image 214/214 /home/ubuntu/vinbigdata/DemoConversionToJPG/12cea68e4b795e545877708c16b8dbdd.jpg: 1024x864 2 Pneumothoraxs, Done. (0.171s)
# Speed: 0.5ms pre-process, 178.8ms inference, 1.0ms NMS per image at shape (1, 3, 1024, 1024)
# Results saved to runs/detect/exp
# 191 labels saved to runs/detect/exp/labels
# HBox(children=(FloatProgress(value=0.0, max=191.0), HTML(value='')))
# 100
# 200
# 214
# Time to send images with predictions to SingleStore: 4.5 seconds
# CPU times: user 3.92 s, sys: 193 ms, total: 4.12 s
# Wall time: 1min 1s

# %%
df
# Out:
#                                  file  \
# 0    056815f22ac3de9b9eb6fb963d4cfa5a
# 1    0bfd35d7f2b63b1ef799fefb18605191
# 2    079de341c7b3804c37114b8da3011b45
# 3    0764ce517782604a7b81bb6e17c798e9
# 4    0c6f7b76bcc012fc5a9af4470f735aba
# ..                                ...
# 209  07cdcea9a6c3049d7a02ade9c680d4d7
# 210  07fecb6f57a3d452c4764b1013740141
# 211  0ce3ae82d1f5c69f253432c5ec47c1be
# 212  090a90ca6e01ed9f613578c95c151a01
# 213  11b8e52dde21c314c67ead9547b1002a
#
#                                       PredictionString
# 0                                         14 1 0 0 1 1
# 1    0 0.9 1613 674 1859 905 3 0.9 1293 1485 2296 2027
# 2     3 0.7 852 1298 1617 1571 0 0.9 1118 638 1310 861
# 3    11 0.4 1448 389 1797 444 11 0.6 610 363 1067 5...
# 4    5 0.3 318 712 1085 2064 11 0.8 681 210 943 336...
# ..                                                 ...
# 209  13 0.4 1752 1455 1861 1597 7 0.5 1749 1410 189...
# 210  13 0.5 1722 1209 1851 1238 3 0.9 799 1344 1724...
# 211  11 0.3 1878 252 2211 342 5 0.8 696 360 1521 17...
# 212                           5 0.2 1142 382 1895 1806
# 213   3 0.6 724 1258 1571 1505 0 0.9 1090 581 1272 783
#
# [214 rows x 2 columns]

# %% [markdown]
# <a name="predictions2"></a>

# %% [markdown]
# - [Back to Contents](#contents2)

# %% [markdown]
# # Send final predictions back to SingleStore

# %%
# %%time

s2conn = pymysql.connect(
    user='root',
    password='Sglstrpw34',
    host='172.31.62.112',
    port=3306,
    database='PatientRecords')

for ind in df.index:
    InFile = df['file'][ind]
    InPredictionString = df['PredictionString'][ind]
    mycursor = s2conn.cursor()
    sql = "call InsertImagePredictions('" + InFile + "','" + InPredictionString + "')"
    mycursor.execute(sql)
    s2conn.commit()
  
mycursor.close()
s2conn.close()
# Out:
# CPU times: user 32.4 ms, sys: 2.32 ms, total: 34.7 ms
# Wall time: 1.56 s

# %% [markdown]
# ## Prediction Strings and Images with Predictions are now sent to SingleStore

# %% [markdown]
# # Example with 11 Dicom Image

# %% [markdown]
# ## Imports and functions

# %%
# %%time
# Imports
# !pip install PyMySQL
# !pip install torchvision
import numpy as np, pandas as pd
from glob import glob
import shutil, os
import matplotlib.pyplot as plt
from sklearn.model_selection import GroupKFold
from tqdm.notebook import tqdm
import seaborn as sns
import os
import torch
from IPython.display import Image, clear_output
import time
from tqdm.notebook import tqdm
import pymysql
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')


# Model format conversion
def yolo2voc(image_height, image_width, bboxes):
    """
    yolo => [xmid, ymid, w, h] (normalized)
    voc  => [x1, y1, x2, y1]
    
    """ 
    bboxes = bboxes.copy().astype(float) # otherwise all value will be 0 as voc_pascal dtype is np.int
    
    bboxes[..., [0, 2]] = bboxes[..., [0, 2]]* image_width
    bboxes[..., [1, 3]] = bboxes[..., [1, 3]]* image_height
    
    bboxes[..., [0, 1]] = bboxes[..., [0, 1]] - bboxes[..., [2, 3]]/2
    bboxes[..., [2, 3]] = bboxes[..., [0, 1]] + bboxes[..., [2, 3]]
    
    return bboxes

# Functions
def GeneralEnsemble(dets, iou_thresh = 0.5, weights=None):
    assert(type(iou_thresh) == float)
    
    ndets = len(dets)
    
    if weights is None:
        w = 1/float(ndets)
        weights = [w]*ndets
    else:
        assert(len(weights) == ndets)
        
        s = sum(weights)
        for i in range(0, len(weights)):
            weights[i] /= s

    out = list()
    used = list()
    
    for idet in range(0,ndets):
        det = dets[idet]
        for box in det:
            if box in used:
                continue
                
            used.append(box)
            # Search the other detectors for overlapping box of same class
            found = []
            for iodet in range(0, ndets):
                odet = dets[iodet]
                
                if odet == det:
                    continue
                
                bestbox = None
                bestiou = iou_thresh
                for obox in odet:
                    if not obox in used:
                        # Not already used
                        if box[4] == obox[4]:
                            # Same class
                            iou = computeIOU(box, obox)
                            if iou > bestiou:
                                bestiou = iou
                                bestbox = obox
                                
                if not bestbox is None:
                    w = weights[iodet]
                    found.append((bestbox,w))
                    used.append(bestbox)
                            
            # Now we've gone through all other detectors
            if len(found) == 0:
                new_box = list(box)
                new_box[5] /= ndets
                out.append(new_box)
            else:
                allboxes = [(box, weights[idet])]
                allboxes.extend(found)
                
                xc = 0.0
                yc = 0.0
                bw = 0.0
                bh = 0.0
                conf = 0.0
                
                wsum = 0.0
                for bb in allboxes:
                    w = bb[1]
                    wsum += w

                    b = bb[0]
                    xc += w*b[0]
                    yc += w*b[1]
                    bw += w*b[2]
                    bh += w*b[3]
                    conf += w*b[5]
                    #print(f"conf = {conf}")
                
                xc /= wsum
                yc /= wsum
                bw /= wsum
                bh /= wsum    

                new_box = [xc, yc, bw, bh, box[4], conf]
                out.append(new_box)
    return out
    
def getCoords(box):
    x1 = float(box[0]) - float(box[2])/2
    x2 = float(box[0]) + float(box[2])/2
    y1 = float(box[1]) - float(box[3])/2
    y2 = float(box[1]) + float(box[3])/2
    return x1, x2, y1, y2
    
def computeIOU(box1, box2):
    x11, x12, y11, y12 = getCoords(box1)
    x21, x22, y21, y22 = getCoords(box2)
    
    x_left   = max(x11, x21)
    y_top    = max(y11, y21)
    x_right  = min(x12, x22)
    y_bottom = min(y12, y22)

    if x_right < x_left or y_bottom < y_top:
        return 0.0    
        
    intersect_area = (x_right - x_left) * (y_bottom - y_top)
    box1_area = (x12 - x11) * (y12 - y11)
    box2_area = (x22 - x21) * (y22 - y21)        
    
    iou = intersect_area / (box1_area + box2_area - intersect_area)
    return iou

# Function to transform the YOLOV5 output to the format the Ensemble function expects. 

def transform_object(df,tmp,flag):
    list_of_floats=[]
    for item in tmp:
        list_of_floats.append(float(item))
        
    tm=int(len(list_of_floats)/6)
    list1=[]
    list2=[]
    checkobj=[]
    for i in range(tm):
          
        j=i*6
        k=j
        l=k+6
            
        checkobj.append(k)
        xmin=list_of_floats[k+2]
        ymin=list_of_floats[k+3]
        xmax=list_of_floats[k+4]
        ymax=list_of_floats[k+5]
            
        box_w=xmax-xmin
        box_h=ymax-ymin
        box_x=xmin+(box_w/2)
        box_y=ymin+box_h/2
            
        list1=[box_x,box_y,box_w,box_h,int(list_of_floats[k]),list_of_floats[k+1]]
        
        list2.append(list1)        
        list1=[]
    if flag==0:
        return checkobj
    else:
        return list2
    
#https://www.kaggle.com/prashantkikani/vinbigdata-ensemble-post-processing?scriptVersionId=56245340

def divide(l, n):
    '''
    divide submission string into group of 6
    '''
    for i in range(0, len(l), n):  
        yield l[i:i + n]
# Out:
# CPU times: user 0 ns, sys: 91 µs, total: 91 µs
# Wall time: 96.3 µs

# %%
# %%time


# Bring Dicom metadata back from SingleStore


os.chdir('/home/ubuntu/vinbigdata/')
s2conn = create_engine('mysql+pymysql://root:Sglstrpw34@172.31.62.112:3306/PatientRecords')

test_df = pd.read_sql_table('ImageHeaderdf', s2conn)


# Run Yolov5 Ensemble model on new JPG folder


fold_exp = ['exp26']
test_dir = f'/home/ubuntu/vinbigdata/1DemoConversionToJPG/'
os.chdir('/home/ubuntu/vinbigdata/yolov5')

for fold, exp in enumerate(fold_exp):
    weights_dir = f'/home/ubuntu/vinbigdata/yolov5/runs/train/exp26/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp27/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp28/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp29/weights/best.pt /home/ubuntu/vinbigdata/yolov5/runs/train/exp30/weights/best.pt'
    os.chdir('/home/ubuntu/vinbigdata/yolov5/')
    
    # !python detect.py --weights $weights_dir\
    --img 1024\
    --conf 0.2\
    --iou 0.4\
    --source $test_dir\
    --save-txt --save-conf --exist-ok
    

# Convert Yolo predictions to PascalVoc format, back to the original Dicom Size
    
    
    image_ids = []
    PredictionStrings = []

    for file_path in tqdm(glob('runs/detect/exp/labels/*txt')):
        image_id = file_path.split('/')[-1].split('.')[0]
        w, h = test_df.loc[test_df.file==image_id,['Columns', 'Rows']].values[0]
        f = open(file_path, 'r')
        data = np.array(f.read().replace('\n', ' ').strip().split(' ')).astype(np.float32).reshape(-1, 6)
        data = data[:, [0, 5, 1, 2, 3, 4]]
        bboxes = list(np.round(np.concatenate((data[:, :2], np.round(yolo2voc(h, w, data[:, 2:]))), axis =1).reshape(-1), 1).astype(str))
        for idx in range(len(bboxes)):
            bboxes[idx] = str(int(float(bboxes[idx]))) if idx%6!=1 else bboxes[idx]
        image_ids.append(image_id)
        PredictionStrings.append(' '.join(bboxes))

    # credit / source: https://www.kaggle.com/awsaf49/vinbigdata-cxr-ad-yolov5-14-class-infer
    pred_df = pd.DataFrame({'file':image_ids,
                            'PredictionString':PredictionStrings})
    df = pd.merge(test_df, pred_df, on = 'file', how = 'left').fillna("14 1 0 0 1 1")
    df = df[['file', 'PredictionString']]

    os.chdir('/home/ubuntu/vinbigdata/')


def convertToBinaryData(ImageFile):
    # Convert digital data to binary format
    with open(ImageFile, 'rb') as file:
        binaryData = file.read()
    return binaryData


def updateBLOB(ImageID, ImagePath, ImageFile):
    #print("Inserting BLOB into JPGImages table")
    # try:
    mycursor = s2conn.cursor()

    sql_update_blob_query = """ Update JPGImages 
                        set PredictionImage = %s 
                        where file = %s """

    jpgImage = convertToBinaryData(ImageFile)

    # Convert data into tuple format
    insert_blob_tuple = (jpgImage, ImageID)
    result = mycursor.execute(sql_update_blob_query, insert_blob_tuple)
    s2conn.commit()
    mycursor.close()
    

# Send images with predictions to SingleStore


directory = '/home/ubuntu/vinbigdata/yolov5/runs/detect/exp'
jpgCount = 0

start = time.time()

s2conn = pymysql.connect(
    user='root',
    password='Sglstrpw34',
    host='172.31.62.112',
    port=3306,
    database='Images')

for filename in os.listdir(directory):
        f = os.path.join(directory, filename)
        file = os.path.splitext(os.path.basename(os.path.basename(f)))[0]

        # checking if it is a file
        if os.path.isfile(f) and f.endswith(".jpg"):
            updateBLOB(file, directory, f)
            jpgCount += 1
            if jpgCount % 100 == 0:
                print (jpgCount)
print(jpgCount)

s2conn.close()
# end = time.time()
# print(f'Time to send images with predictions to SingleStore: {round((end - start),2)} seconds')


# Clear image prediction folders for reusability


dir = '/home/ubuntu/vinbigdata/yolov5/runs/detect/exp/'
for files in os.listdir(dir):
    path = os.path.join(dir, files)
    try:
        shutil.rmtree(path)
    except OSError:
        os.remove(path)
        

# Send prediction strings to SingleStore

# start = time.time()
s2conn = pymysql.connect(
    user='root',
    password='Sglstrpw34',
    host='172.31.62.112',
    port=3306,
    database='PatientRecords')

for ind in df.index:
    InFile = df['file'][ind]
    InPredictionString = df['PredictionString'][ind]
    mycursor = s2conn.cursor()
    sql = "call InsertImagePredictions('" + InFile + "','" + InPredictionString + "')"
    mycursor.execute(sql)
    s2conn.commit()
  
mycursor.close()
s2conn.close()
end = time.time()
print(f'Time to send prediction string and prediction images to SingleStore: {round((end - start),2)} seconds')
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# detect: weights=['/home/ubuntu/vinbigdata/yolov5/runs/train/exp26/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp27/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp28/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp29/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp30/weights/best.pt'], source=/home/ubuntu/vinbigdata/1DemoConversionToJPG/, imgsz=[1024, 1024], conf_thres=0.2, iou_thres=0.4, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-115-gbc48457 torch 1.10.0+cu102 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Fusing layers...
# Model Summary: 444 layers, 86260891 parameters, 0 gradients
# Ensemble created with ['/home/ubuntu/vinbigdata/yolov5/runs/train/exp26/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp27/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp28/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp29/weights/best.pt', '/home/ubuntu/vinbigdata/yolov5/runs/train/exp30/weights/best.pt']
#
# image 1/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0168eb925aa6f28a78b16134792f5d0e.jpg: 1024x864 1 Consolidation, 1 Pneumothorax, Done. (0.179s)
# image 2/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/043111cdad4d26204503d3396876046f.jpg: 1024x1024 1 Consolidation, 1 Pneumothorax, 1 ILD, Done. (0.188s)
# image 3/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c15e19c74ef8ddd9bed0a4fc7f4b5a8.jpg: 1024x864 1 Aortic enlargement, 1 Pneumothorax, Done. (0.181s)
# image 4/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c187ebe652499a7e28fd93da2e42ebb.jpg: 1024x864 1 Other lesion, Done. (0.171s)
# image 5/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c26e997c79d2a3149cf1a62c9444554.jpg: 1024x1024 1 Pneumothorax, Done. (0.188s)
# image 6/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c5bc5fdf756d1251e431c9281349376.jpg: 1024x864 1 Pneumothorax, Done. (0.180s)
# image 7/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c6036df3708fe77c1c76498240d6774.jpg: 1024x864 1 Atelectasis, 1 Pleural effusion, 1 Other lesion, 1 Infiltration, Done. (0.171s)
# image 8/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c6f7b76bcc012fc5a9af4470f735aba.jpg: 1024x896 1 Atelectasis, 1 Nodule/Mass, 1 Pneumothorax, Done. (0.182s)
# image 9/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c785dff51447d6e689e15dcfe10c8e2.jpg: 1024x864 1 Atelectasis, 1 Other lesion, 1 Aortic enlargement, 1 Infiltration, 1 Consolidation, 1 Pneumothorax, Done. (0.179s)
# image 10/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c803c4810a8c5ec362f5d4504489431.jpg: 1024x864 1 Atelectasis, 1 Other lesion, 2 Pneumothoraxs, Done. (0.171s)
# image 11/11 /home/ubuntu/vinbigdata/1DemoConversionToJPG/0c84dad44979c3a7777a8f4f4d9f5f7a.jpg: 1024x864 1 Atelectasis, 1 Other lesion, Done. (0.172s)
# Speed: 0.5ms pre-process, 178.3ms inference, 1.3ms NMS per image at shape (1, 3, 1024, 1024)
# Results saved to runs/detect/exp
# 11 labels saved to runs/detect/exp/labels
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))
# 11
# Time to send prediction string and prediction images to SingleStore: 0.29 seconds
# CPU times: user 423 ms, sys: 58.7 ms, total: 481 ms
# Wall time: 14.2 s

# %% [markdown]
# - [Back to Contents](#contents2)
