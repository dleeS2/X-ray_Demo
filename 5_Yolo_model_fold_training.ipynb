# %%
# !pip install wandb

# %%
import torch
import os
import wandb
import gc

# %%
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: insigh1 (use `wandb login --relogin` to force relogin)
# True

# %%
print(torch._C._cuda_getCompiledVersion(), 'cuda compiled version')
# Out:
# 10020 cuda compiled version

# %%
# !pwd
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/vinbigdata

# %%
os.chdir('yolov5')

# %%
# Change folds in each training test non-distributed
# !python train.py --img 1024 --batch 8 --epochs 6 --data /home/ubuntu/vinbigdata/k-folds/images/0/vinbigdata_0.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --workers 16
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# wandb: Currently logged in as: insigh1 (use `wandb login --relogin` to force relogin)
# train: weights=yolov5x.pt, cfg=./models/yolov5x.yaml, data=/home/ubuntu/vinbigdata/k-folds/images/0/vinbigdata_0.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=6, batch_size=8, imgsz=1024, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=16, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# ...

# %%
# Change folds in each training k-fold0
# !python train.py --img 1024 --batch 4 --epochs 3 --data /home/ubuntu/vinbigdata/k-folds/images/0/vinbigdata_0.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --workers 8

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.get_device_name(0)
# Out:
# 'Tesla V100-SXM2-16GB'

# %%
torch.cuda.get_device_name(7)
# Out:
# 'Tesla V100-SXM2-16GB'

# %%
# k-fold0
# !python -m torch.distributed.launch --nproc_per_node 8 train.py --img 1024 --epochs 60 --batch 32 --data /home/ubuntu/vinbigdata/k-folds/images/0/vinbigdata_0.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --device 0,1,2,3,4,5,6,7
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# ...

# %%
# k-fold0
# !python -m torch.distributed.launch --nproc_per_node 8 train.py --img 1024 --epochs 60 --batch 32 --data /home/ubuntu/vinbigdata/k-folds/images/0/vinbigdata_0.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --device 0,1,2,3,4,5,6,7
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# ...

# %%
gc.collect()
torch.cuda.empty_cache()
# Out:
# 133

# %%
torch.cuda.empty_cache()

# %%
# # k-fold1
# !python -m torch.distributed.launch --nproc_per_node 8 train.py --img 1024 --epochs 60 --batch 32 --data /home/ubuntu/vinbigdata/k-folds/images/1/vinbigdata_1.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --device 0,1,2,3,4,5,6,7
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# ...

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
# # k-fold2
# !python -m torch.distributed.launch --nproc_per_node 8 train.py --img 1024 --epochs 60 --batch 32 --data /home/ubuntu/vinbigdata/k-folds/images/2/vinbigdata_2.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --device 0,1,2,3,4,5,6,7
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# ...

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
# k-fold3
# !python -m torch.distributed.launch --nproc_per_node 8 train.py --img 1024 --epochs 60 --batch 32 --data /home/ubuntu/vinbigdata/k-folds/images/3/vinbigdata_3.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --device 0,1,2,3,4,5,6,7
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# ...

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
# k-fold4
# !python -m torch.distributed.launch --nproc_per_node 8 train.py --img 1024 --epochs 60 --batch 32 --data /home/ubuntu/vinbigdata/k-folds/images/4/vinbigdata_4.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --device 0,1,2,3,4,5,6,7
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# ...

# %%
# !pwd
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/vinbigdata/yolov5

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
# k-fold4
# !python -m torch.distributed.launch --nproc_per_node 8 train.py --img 1024 --epochs 100 --batch 32 --data /home/ubuntu/vinbigdata/vinbigdata.yaml --cache --cfg ./models/yolov5x.yaml --weights yolov5x.pt --device 0,1,2,3,4,5,6,7
# Out:
# /bin/bash: switchml: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `switchml'
# /bin/bash: _moduleraw: line 1: syntax error: unexpected end of file
# /bin/bash: error importing function definition for `_moduleraw'
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# ...

# %%
# runs/train/exp26 k-fold0 - done
# runs/train/exp27 k-fold1 - done
# runs/train/exp28 k-fold2 - done
# runs/train/exp29 k-fold3 - done
# runs/train/exp30 k-fold4 - done

# runs/train/exp30 k-fold5 - wip  # large
